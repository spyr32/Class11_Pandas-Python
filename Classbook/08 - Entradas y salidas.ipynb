# %% [markdown]
# # Entradas y salidas

# %%
import numpy as np
import pandas as pd

# Definimos un dataframe con datos de ejemplos
df = pd.DataFrame(np.random.randn(10, 5), columns=["A", "B", "C", "D", "E"])

df
# Out:
#           A         B         C         D         E
# 0 -1.342242  0.240154 -0.151237 -0.362385 -0.566443
# 1  0.342630  0.053872 -1.274392  0.351900 -0.934074
# 2  1.588026  0.963862 -1.538995 -0.026888  0.668458
# 3  0.472814  0.303408 -1.358858 -0.315345 -1.683170
# 4 -1.165295 -0.957003 -1.238517 -0.141548  1.014346
# 5 -1.942757 -0.174568 -1.705833 -2.173668  1.023161
# 6  0.276933 -0.046801 -0.418761  0.594661  1.163008
# 7 -1.307002  1.740001  0.025230  0.642172 -0.861325
# 8 -0.263554 -0.468449  0.073063  0.831934 -0.895484
# 9 -1.279905 -2.272489 -0.060485  0.796107 -0.283489

# %% [markdown]
# ## CSV
#
# ### Guardar a CSV

# %%
df.to_csv('datos.csv', index=False)

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde CSV

# %%
df = pd.read_csv('datos.csv')

df
# Out:
#           A         B         C         D         E
# 0 -1.342242  0.240154 -0.151237 -0.362385 -0.566443
# 1  0.342630  0.053872 -1.274392  0.351900 -0.934074
# 2  1.588026  0.963862 -1.538995 -0.026888  0.668458
# 3  0.472814  0.303408 -1.358858 -0.315345 -1.683170
# 4 -1.165295 -0.957003 -1.238517 -0.141548  1.014346
# 5 -1.942757 -0.174568 -1.705833 -2.173668  1.023161
# 6  0.276933 -0.046801 -0.418761  0.594661  1.163008
# 7 -1.307002  1.740001  0.025230  0.642172 -0.861325
# 8 -0.263554 -0.468449  0.073063  0.831934 -0.895484
# 9 -1.279905 -2.272489 -0.060485  0.796107 -0.283489

# %% [markdown]
# ## JSON
#
# ### Guardar a JSON

# %%
df.to_json('datos.json')

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde JSON

# %%
df = pd.read_json('datos.json')

df
# Out:
#           A         B         C         D         E
# 0 -1.342242  0.240154 -0.151237 -0.362385 -0.566443
# 1  0.342630  0.053872 -1.274392  0.351900 -0.934074
# 2  1.588026  0.963862 -1.538995 -0.026888  0.668458
# 3  0.472814  0.303408 -1.358858 -0.315345 -1.683170
# 4 -1.165295 -0.957003 -1.238517 -0.141548  1.014346
# 5 -1.942757 -0.174568 -1.705833 -2.173668  1.023161
# 6  0.276933 -0.046801 -0.418761  0.594661  1.163008
# 7 -1.307002  1.740001  0.025230  0.642172 -0.861325
# 8 -0.263554 -0.468449  0.073063  0.831934 -0.895484
# 9 -1.279905 -2.272489 -0.060485  0.796107 -0.283489

# %% [markdown]
# ## Excel
#
# Necesitamos instalar el módulo `openpyxl` para generar y leer este formato:
#
#     pip install openpyxl

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\antho\appdata\local\programs\python\python312\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\antho\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Guardar a Excel

# %%
df.to_excel('datos.xlsx', sheet_name='Sheet1', index=False)

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde Excel

# %%
df = pd.read_excel('datos.xlsx', sheet_name='Sheet1')

df
# Out:
#           A         B         C         D         E
# 0 -1.342242  0.240154 -0.151237 -0.362385 -0.566443
# 1  0.342630  0.053872 -1.274392  0.351900 -0.934074
# 2  1.588026  0.963862 -1.538995 -0.026888  0.668458
# 3  0.472814  0.303408 -1.358858 -0.315345 -1.683170
# 4 -1.165295 -0.957003 -1.238517 -0.141548  1.014346
# 5 -1.942757 -0.174568 -1.705833 -2.173668  1.023161
# 6  0.276933 -0.046801 -0.418761  0.594661  1.163008
# 7 -1.307002  1.740001  0.025230  0.642172 -0.861325
# 8 -0.263554 -0.468449  0.073063  0.831934 -0.895484
# 9 -1.279905 -2.272489 -0.060485  0.796107 -0.283489

# %% [markdown]
# Con `Matplotlib`, que aprenderemos en la próxima sección, podemos graficar estos resultados fácilmente:

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = 10,5

fertility_rate.mean()[1:].plot(kind='line', xlabel="Períodos", ylabel="Media de natalidad mundial")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       1 import matplotlib.pyplot as plt
#       2 plt.rcParams["figure.figsize"] = 10,5
# ----> 4 fertility_rate.mean()[1:].plot(kind='line', xlabel="Períodos", ylabel="Media de natalidad mundial")
#
# NameError: name 'fertility_rate' is not defined

# %% [markdown]
# La práctica hace el maestro, os animo a hacer vuestras propias pruebas y googlear cualquier cosa que se os ocurra para aprender mucho más.
